# %% [markdown]
# <a href="https://colab.research.google.com/github/Nainsarkee100/English-Myanmar-Dictionary/blob/main/CognitiveComputingLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Sentiment Classifier (Rule-Based)

def classify_sentiment(sentence):
    # Convert sentence to lowercase
    sentence = sentence.lower()

    # Define positive and negative word lists
    positive_words = ["good", "happy", "great", "excellent", "love", "amazing", "nice"]
    negative_words = ["bad", "sad", "terrible", "awful", "hate", "poor", "worst"]

    positive_score = 0
    negative_score = 0

    # Split sentence into words
    words = sentence.split()

    # Count positive and negative words
    for word in words:
        if word in positive_words:
            positive_score += 1
        elif word in negative_words:
            negative_score += 1

    # Classification logic
    if positive_score > negative_score:
        return "Positive"
    elif negative_score > positive_score:
        return "Negative"
    else:
        return "Neutral"


# Test
user_input = input("Enter a sentence: ")
result = classify_sentiment(user_input)
print("Sentiment:", result)
# Out:
# Enter a sentence: Today will be a better day
# Sentiment: Neutral

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7dfcaa32-b28c-42b0-acc2-c46363273fbd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7dfcaa32-b28c-42b0-acc2-c46363273fbd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                             title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# amar5693/screen-time-sleep-and-stress-analysis-dataset          Screen Time, Sleep & Stress Analysis Dataset            787136  2026-02-13 06:56:18.757000           7071        139  1.0
# amar5693/student-performance-dataset                            Student Performance Dataset                             177286  2026-02-12 06:04:44.613000           6097         97  1.0
# aliiihussain/amazon-sales-dataset                               Amazon_Sales_Dataset                                   1297759  2026-02-01 11:37:12.353000           8673        137  1.0
# ...

# %%
# !kaggle datasets download -d lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# License(s): other
# ...
#   0% 0.00/25.7M [00:00<?, ?B/s]
# 100% 25.7M/25.7M [00:00<00:00, 1.08GB/s]

# %%
# !unzip imdb-dataset-of-50k-movie-reviews.zip
# Out:
# Archive:  imdb-dataset-of-50k-movie-reviews.zip
#   inflating: IMDB Dataset.csv

# %%
import pandas as pd

df = pd.read_csv("IMDB Dataset.csv")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (50000, 2)
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
